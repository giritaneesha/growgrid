# %%
import pandas as pd
df = pd.read_csv('/Users/keva/Downloads/finance_loan_portfolio_python_dataset.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_ID                1230 non-null   object
#  1   Customer_ID              1230 non-null   object
#  2   Customer_Name            1230 non-null   object
#  3   Age                      1202 non-null   float64
#  4   Gender                   1208 non-null   object
#  5   City                     1198 non-null   object
#  6   Employment_Type          1205 non-null   object
#  7   Annual_Income_INR        1196 non-null   float64
#  8   Credit_Score             1188 non-null   float64
#  9   Loan_Type                1230 non-null   object
#  10  Loan_Amount_INR          1230 non-null   int64
#  11  Interest_Rate_Pct        1212 non-null   float64
#  12  Loan_Term_Months         1230 non-null   int64
#  13  Monthly_EMI_INR          1230 non-null   float64
# ...

# %%
plt.hist(df["Age"])
plt.title("Histogram for Age")
# Out:
# Text(0.5, 1.0, 'Histogram for Age')

# %%
plt.hist(df["Age"])
plt.title("Histogram for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Age"],kde=True)
plt.title("Histogram for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.countplot(x = df["Gender"])
plt.title("Count of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(x=df["Age"],bins=20)
plt.title("Histogram for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Annual_Income_INR"])
plt.title("Histogram for Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Credit_Score"])
plt.title("Histogram for Credit Score")
plt.xlabel("Credit Score")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Loan_Amount_INR"])
plt.title("Histogram for Loan Amount")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Interest_Rate_Pct"])
plt.title("Histogram for Interest Rate")
plt.xlabel("Interest Rate")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Loan_Term_Months"])
plt.title("Histogram for Loan Term")
plt.xlabel("Loan Term (Months)")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Monthly_EMI_INR"])
plt.title("Histogram for Monthly EMI")
plt.xlabel("Monthly EMI")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Outstanding_Balance_INR"])
plt.title("Histogram for Outstanding Balance")
plt.xlabel("Outstanding Balance")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Days_Past_Due"])
plt.title("Histogram for Days Past Due")
plt.xlabel("Days Past Due")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Late_Payment_Count"])
plt.title("Histogram for Late Payment Count")
plt.xlabel("Late Payment Count")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Debt_to_Income_Ratio"])
plt.title("Histogram for Debt to Income Ratio")
plt.xlabel("Debt to Income Ratio")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Savings_Balance_INR"])
plt.title("Histogram for Savings Balance")
plt.xlabel("Savings Balance")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(x=df["Investment_Value_INR"])
plt.title("Histogram for Investment Value")
plt.xlabel("Investment Value")
plt.ylabel("Frequency")
plt.show()

# %%
df["City"].value_counts().plot(kind="bar")
plt.title("Count of City")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %%
df["Employment_Type"].value_counts().plot(kind="bar")
plt.title("Count of Employment Type")
plt.xlabel("Employment Type")
plt.ylabel("Count")
plt.show()

# %%
df["Loan_Type"].value_counts().plot(kind="bar")
plt.title("Count of Loan Type")
plt.xlabel("Loan Type")
plt.ylabel("Count")
plt.show()

# %%
df["Payment_Status"].value_counts().plot(kind="bar")
plt.title("Count of Payment Status")
plt.xlabel("Payment Status")
plt.ylabel("Count")
plt.show()

# %%
df["Default_Flag"].value_counts().plot(kind="bar")
plt.title("Count of Default Flag")
plt.xlabel("Default Flag")
plt.ylabel("Count")
plt.show()

# %%
df["Risk_Category"].value_counts().plot(kind="bar")
plt.title("Count of Risk Category")
plt.xlabel("Risk Category")
plt.ylabel("Count")
plt.show()

# %%
df["Payment_Mode"].value_counts().plot(kind="bar")
plt.title("Count of Payment Mode")
plt.xlabel("Payment Mode")
plt.ylabel("Count")
plt.show()

# %%
df["Acquisition_Channel"].value_counts().plot(kind="bar")
plt.title("Count of Acquisition Channel")
plt.xlabel("Acquisition Channel")
plt.ylabel("Count")
plt.show()

# %%
df["Branch_Name"].value_counts().plot(kind="bar")
plt.title("Count of Branch Name")
plt.xlabel("Branch Name")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(x=df["City"],hue=df["Gender"])
plt.title("Countplot for City and Gender")
plt.xlabel("City")
plt.xticks(rotation = 90 )
plt.show()

# %%
sns.countplot(x=df["Loan_Type"],hue=df["Payment_Status"])
plt.title("Loan Type vs Payment Status")
plt.xticks(rotation=90)
plt.show()

# %%
#categorical vs numerical columns

sns.barplot
# Out:
# <function seaborn.categorical.barplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, seed=None, units=None, weights=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, hue_norm=None, width=0.8, dodge='auto', gap=0, log_scale=None, native_scale=False, formatter=None, legend='auto', capsize=0, err_kws=None, ci=<deprecated>, errcolor=<deprecated>, errwidth=<deprecated>, ax=None, **kwargs)>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_ID                1230 non-null   object
#  1   Customer_ID              1230 non-null   object
#  2   Customer_Name            1230 non-null   object
#  3   Age                      1202 non-null   float64
#  4   Gender                   1208 non-null   object
#  5   City                     1198 non-null   object
#  6   Employment_Type          1205 non-null   object
#  7   Annual_Income_INR        1196 non-null   float64
#  8   Credit_Score             1188 non-null   float64
#  9   Loan_Type                1230 non-null   object
#  10  Loan_Amount_INR          1230 non-null   int64
#  11  Interest_Rate_Pct        1212 non-null   float64
#  12  Loan_Term_Months         1230 non-null   int64
#  13  Monthly_EMI_INR          1230 non-null   float64
# ...

# %%
#categorical vs numerical columnss

sns.barplot(x=df["Gender"],y=df["Annual_Income_INR"])
plt.title("Gender wise Annual Income")
plt.show()

# %%
#boxplot for categorical vs numerical data

sns. boxplot(x=df ["Loan_Type"], y=df ["Loan_Amount_INR"])
plt.title("Loan type vs Loan Amount Analysis")
plt.xlabel("Loan Type")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Gender"], y=df["Age"])
plt.title("Gender vs Age")
plt.xlabel("Gender")
plt.ylabel("Age")
plt.show()

# %%
sns.boxplot(x=df["Loan_Type"], y=df["Loan_Amount_INR"])
plt.title("Loan Type vs Loan Amount")
plt.xlabel("Loan Type")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Employment_Type"], y=df["Annual_Income_INR"])
plt.title("Employment Type vs Annual Income")
plt.xlabel("Employment Type")
plt.ylabel("Annual Income")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["Payment_Status"], y=df["Credit_Score"])
plt.title("Payment Status vs Credit Score")
plt.xlabel("Payment Status")
plt.ylabel("Credit Score")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x=df["City"], y=df["Loan_Amount_INR"])
plt.title("City vs Loan Amount")
plt.xlabel("City")
plt.ylabel("Loan Amount")
plt.xticks(rotation=90)
plt.show()

# %%
#Numerical vs Numerical – Scatter Plot
sns. scatterplot(x=df["Annual_Income_INR"], y=df ["Loan_Amount_INR"])
plt.title("Annual Income vs Loan Amount")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.scatterplot(x=df["Annual_Income_INR"], y=df["Loan_Amount_INR"])
plt.title("Annual Income vs Loan Amount")
plt.xlabel("Annual Income")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.scatterplot(x=df["Age"], y=df["Loan_Amount_INR"])
plt.title("Age vs Loan Amount")
plt.xlabel("Age")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.scatterplot(x=df["Credit_Score"], y=df["Loan_Amount_INR"])
plt.title("Credit Score vs Loan Amount")
plt.xlabel("Credit Score")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.scatterplot(x=df["Age"], y=df["Annual_Income_INR"])
plt.title("Age vs Annual Income")
plt.xlabel("Age")
plt.ylabel("Annual Income")
plt.show()

# %%
sns.scatterplot(x=df["Loan_Term_Months"], y=df["Loan_Amount_INR"])
plt.title("Loan Term vs Loan Amount")
plt.xlabel("Loan Term")
plt.ylabel("Loan Amount")
plt.show()

# %%
#Bar/Count Plot (Categorical vs Categorical)
sns.countplot(x=df["City"], hue=df["Gender"])
plt.title("City vs Gender")
plt.xlabel("City")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["Loan_Type"], hue=df["Payment_Status"])
plt.title("Loan Type vs Payment Status")
plt.xlabel("Loan Type")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["Gender"], hue=df["Employment_Type"])
plt.title("Gender vs Employment Type")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(x=df["City"], hue=df["Loan_Type"])
plt.title("City vs Loan Type")
plt.xlabel("City")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=df["Employment_Type"], hue=df["Payment_Status"])
plt.title("Employment Type vs Payment Status")
plt.xlabel("Employment Type")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()
