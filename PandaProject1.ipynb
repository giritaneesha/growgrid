# %%
import pandas as pd
df = pd.read_csv('/Users/keva/Downloads/finance_loan_portfolio_python_dataset.csv')

# %%
df.head()
# Out:
#    Record_ID Customer_ID    Customer_Name   Age  Gender     City  \
# 0  FIN-00255  CUST-00839      Arjun Gupta  64.0  Female   Jaipur
# 1  FIN-00474  CUST-00508       Rohan Iyer  63.0    Male   Mumbai
# 2  FIN-00725  CUST-00013     Rohan Jadhav  48.0  Female  Lucknow
# 3  FIN-00438  CUST-00328  Tanvi Chaudhary  56.0    Male   Nashik
# 4  FIN-00661  CUST-00740       Rahul Iyer  53.0  Female   Nashik
#
#        Employment_Type  Annual_Income_INR  Credit_Score      Loan_Type  ...  \
# 0        Self-Employed           679000.0         707.0      Home Loan  ...
# 1             Salaried          1275000.0         745.0  Personal Loan  ...
# 2  Government Employee          1390000.0         663.0  Personal Loan  ...
# 3  Government Employee           719000.0         695.0   Vehicle Loan  ...
# 4       Business Owner          7218000.0         665.0      Home Loan  ...
#
#    Late_Payment_Count  Default_Flag  Debt_to_Income_Ratio  \
# 0                   7           Yes                 0.920
# 1                   0            No                 0.386
# 2                   2            No                   NaN
# 3                   1            No                 0.689
# 4                   3            No                 0.075
#
#    Savings_Balance_INR Investment_Value_INR  Risk_Category Last_Payment_Date  \
# 0             42160.72             78362.21           High        2026-05-30
# 1            167007.37            435254.86            Low        2026-07-10
# 2              6378.50                 0.00            Low               NaN
# 3            353397.61            148295.33         Medium        2026-06-24
# 4           1210618.96           1460036.03         Medium        2026-04-24
#
#    Payment_Mode  Acquisition_Channel            Branch_Name
# 0    Auto-Debit              Partner     Nagpur Civil Lines
# 1   Net Banking              Website        Chennai T Nagar
# 2           UPI               Branch            Nashik Road
# 3    Auto-Debit              Website  Delhi Connaught Place
# 4           UPI               Branch        Jaipur C Scheme
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_ID                1230 non-null   object
#  1   Customer_ID              1230 non-null   object
#  2   Customer_Name            1230 non-null   object
#  3   Age                      1202 non-null   float64
#  4   Gender                   1208 non-null   object
#  5   City                     1198 non-null   object
#  6   Employment_Type          1205 non-null   object
#  7   Annual_Income_INR        1196 non-null   float64
#  8   Credit_Score             1188 non-null   float64
#  9   Loan_Type                1230 non-null   object
#  10  Loan_Amount_INR          1230 non-null   int64
#  11  Interest_Rate_Pct        1212 non-null   float64
#  12  Loan_Term_Months         1230 non-null   int64
#  13  Monthly_EMI_INR          1230 non-null   float64
#  14  Disbursement_Date        1230 non-null   object
#  15  Outstanding_Balance_INR  1206 non-null   float64
#  16  Payment_Status           1230 non-null   object
#  17  Days_Past_Due            1230 non-null   int64
#  18  Late_Payment_Count       1230 non-null   int64
#  19  Default_Flag             1230 non-null   object
#  20  Debt_to_Income_Ratio     1195 non-null   float64
#  21  Savings_Balance_INR      1199 non-null   float64
#  22  Investment_Value_INR     1198 non-null   float64
#  23  Risk_Category            1230 non-null   object
#  24  Last_Payment_Date        1203 non-null   object
#  25  Payment_Mode             1210 non-null   object
#  26  Acquisition_Channel      1230 non-null   object
#  27  Branch_Name              1230 non-null   object
# dtypes: float64(9), int64(4), object(15)
# memory usage: 269.2+ KB

# %%
df.shape
# Out:
# (1230, 28)

# %%
df.describe()
# Out:
#                Age  Annual_Income_INR  Credit_Score  Loan_Amount_INR  \
# count  1202.000000       1.196000e+03   1188.000000     1.230000e+03
# mean     42.964226       1.386089e+06    684.171717     1.674126e+06
# std      12.896096       1.028175e+06     74.048875     1.861600e+06
# min      21.000000       2.940000e+05    474.000000     4.500000e+04
# 25%      32.000000       7.382500e+05    634.000000     4.600000e+05
# 50%      43.000000       1.134500e+06    685.000000     9.750000e+05
# 75%      54.000000       1.647500e+06    733.000000     2.201250e+06
# max      65.000000       7.292000e+06    850.000000     1.127000e+07
#
#        Interest_Rate_Pct  Loan_Term_Months  Monthly_EMI_INR  \
# count        1212.000000       1230.000000      1230.000000
# mean           13.708251         70.048780     41653.180146
# std             4.011314         66.095999     43479.570285
# min             7.200000          6.000000      1845.090000
# 25%            10.630000         24.000000     15239.642500
# 50%            13.015000         48.000000     29093.575000
# 75%            16.560000         84.000000     53039.820000
# max            24.000000        300.000000    472335.630000
#
#        Outstanding_Balance_INR  Days_Past_Due  Late_Payment_Count  \
# count             1.206000e+03    1230.000000         1230.000000
# mean              1.034594e+06      27.930894            2.666667
# std               1.720638e+06      48.114059            2.696973
# min               0.000000e+00       0.000000            0.000000
# 25%               0.000000e+00       0.000000            0.000000
# 50%               3.322209e+05       0.000000            2.000000
# 75%               1.249156e+06      44.000000            4.000000
# max               1.047749e+07     180.000000           13.000000
#
#        Debt_to_Income_Ratio  Savings_Balance_INR  Investment_Value_INR
# count           1195.000000         1.199000e+03          1.198000e+03
# mean               0.530249         2.852790e+05          2.484833e+05
# std                0.265499         3.354904e+05          3.662194e+05
# min                0.050000         0.000000e+00          0.000000e+00
# 25%                0.299000         5.866674e+04          1.853671e+04
# 50%                0.494000         1.785311e+05          1.314216e+05
# 75%                0.780000         3.909735e+05          3.178733e+05
# max                0.920000         3.202587e+06          3.942651e+06

# %%
df.describe(include="all")
# Out:
#         Record_ID Customer_ID Customer_Name          Age Gender    City  \
# count        1230        1230          1230  1202.000000   1208    1198
# unique       1200         653           602          NaN      3      15
# top     FIN-00977  CUST-00421   Kabir Verma          NaN   Male  Mumbai
# freq            2           6             8          NaN    596     221
# mean          NaN         NaN           NaN    42.964226    NaN     NaN
# std           NaN         NaN           NaN    12.896096    NaN     NaN
# min           NaN         NaN           NaN    21.000000    NaN     NaN
# 25%           NaN         NaN           NaN    32.000000    NaN     NaN
# 50%           NaN         NaN           NaN    43.000000    NaN     NaN
# 75%           NaN         NaN           NaN    54.000000    NaN     NaN
# max           NaN         NaN           NaN    65.000000    NaN     NaN
#
#        Employment_Type  Annual_Income_INR  Credit_Score      Loan_Type  ...  \
# count             1205       1.196000e+03   1188.000000           1230  ...
# unique               5                NaN           NaN              6  ...
# top           Salaried                NaN           NaN  Personal Loan  ...
# freq               552                NaN           NaN            362  ...
# mean               NaN       1.386089e+06    684.171717            NaN  ...
# std                NaN       1.028175e+06     74.048875            NaN  ...
# min                NaN       2.940000e+05    474.000000            NaN  ...
# 25%                NaN       7.382500e+05    634.000000            NaN  ...
# 50%                NaN       1.134500e+06    685.000000            NaN  ...
# 75%                NaN       1.647500e+06    733.000000            NaN  ...
# max                NaN       7.292000e+06    850.000000            NaN  ...
#
#         Late_Payment_Count  Default_Flag  Debt_to_Income_Ratio  \
# count          1230.000000          1230           1195.000000
# unique                 NaN             2                   NaN
# top                    NaN            No                   NaN
# freq                   NaN          1009                   NaN
# mean              2.666667           NaN              0.530249
# std               2.696973           NaN              0.265499
# min               0.000000           NaN              0.050000
# 25%               0.000000           NaN              0.299000
# 50%               2.000000           NaN              0.494000
# 75%               4.000000           NaN              0.780000
# max              13.000000           NaN              0.920000
#
#         Savings_Balance_INR Investment_Value_INR  Risk_Category  \
# count          1.199000e+03         1.198000e+03           1230
# unique                  NaN                  NaN              3
# top                     NaN                  NaN         Medium
# freq                    NaN                  NaN            514
# mean           2.852790e+05         2.484833e+05            NaN
# std            3.354904e+05         3.662194e+05            NaN
# min            0.000000e+00         0.000000e+00            NaN
# 25%            5.866674e+04         1.853671e+04            NaN
# 50%            1.785311e+05         1.314216e+05            NaN
# 75%            3.909735e+05         3.178733e+05            NaN
# max            3.202587e+06         3.942651e+06            NaN
#
#        Last_Payment_Date  Payment_Mode  Acquisition_Channel  \
# count               1203          1210                 1230
# unique               406             5                    5
# top           2026-07-01    Auto-Debit           Mobile App
# freq                  28           469                  382
# mean                 NaN           NaN                  NaN
# std                  NaN           NaN                  NaN
# min                  NaN           NaN                  NaN
# 25%                  NaN           NaN                  NaN
# 50%                  NaN           NaN                  NaN
# 75%                  NaN           NaN                  NaN
# max                  NaN           NaN                  NaN
#
#                Branch_Name
# count                 1230
# unique                  10
# top     Nagpur Civil Lines
# freq                   134
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [11 rows x 28 columns]

# %%
df.isnull()
# Out:
#       Record_ID  Customer_ID  Customer_Name    Age  Gender   City  \
# 0         False        False          False  False   False  False
# 1         False        False          False  False   False  False
# 2         False        False          False  False   False  False
# 3         False        False          False  False   False  False
# 4         False        False          False  False   False  False
# ...         ...          ...            ...    ...     ...    ...
# 1225      False        False          False  False   False  False
# 1226      False        False          False  False   False  False
# 1227      False        False          False  False   False  False
# 1228      False        False          False  False   False  False
# 1229      False        False          False  False   False  False
#
#       Employment_Type  Annual_Income_INR  Credit_Score  Loan_Type  ...  \
# 0               False              False         False      False  ...
# 1               False              False         False      False  ...
# 2               False              False         False      False  ...
# 3               False              False         False      False  ...
# 4               False              False         False      False  ...
# ...               ...                ...           ...        ...  ...
# 1225            False              False         False      False  ...
# 1226            False              False         False      False  ...
# 1227            False              False         False      False  ...
# 1228            False              False         False      False  ...
# 1229            False              False         False      False  ...
#
#       Late_Payment_Count  Default_Flag  Debt_to_Income_Ratio  \
# 0                  False         False                 False
# 1                  False         False                 False
# 2                  False         False                  True
# 3                  False         False                 False
# 4                  False         False                 False
# ...                  ...           ...                   ...
# 1225               False         False                 False
# 1226               False         False                 False
# 1227               False         False                 False
# 1228               False         False                 False
# 1229               False         False                 False
#
#       Savings_Balance_INR  Investment_Value_INR  Risk_Category  \
# 0                   False                 False          False
# 1                   False                 False          False
# 2                   False                 False          False
# 3                   False                 False          False
# 4                   False                 False          False
# ...                   ...                   ...            ...
# 1225                False                 False          False
# 1226                False                 False          False
# 1227                False                 False          False
# 1228                False                 False          False
# 1229                False                 False          False
#
#       Last_Payment_Date  Payment_Mode  Acquisition_Channel  Branch_Name
# 0                 False         False                False        False
# 1                 False         False                False        False
# 2                  True         False                False        False
# 3                 False         False                False        False
# 4                 False         False                False        False
# ...                 ...           ...                  ...          ...
# 1225              False         False                False        False
# 1226              False         False                False        False
# 1227              False         False                False        False
# 1228              False         False                False        False
# 1229              False         False                False        False
#
# [1230 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# Record_ID                   0
# Customer_ID                 0
# Customer_Name               0
# Age                        28
# Gender                     22
# City                       32
# Employment_Type            25
# Annual_Income_INR          34
# Credit_Score               42
# Loan_Type                   0
# Loan_Amount_INR             0
# Interest_Rate_Pct          18
# Loan_Term_Months            0
# Monthly_EMI_INR             0
# Disbursement_Date           0
# Outstanding_Balance_INR    24
# Payment_Status              0
# Days_Past_Due               0
# Late_Payment_Count          0
# Default_Flag                0
# Debt_to_Income_Ratio       35
# Savings_Balance_INR        31
# Investment_Value_INR       32
# Risk_Category               0
# Last_Payment_Date          27
# Payment_Mode               20
# Acquisition_Channel         0
# Branch_Name                 0
# dtype: int64

# %%
#for numeric values column
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Annual_Income_INR"] = df["Annual_Income_INR"].fillna(df["Annual_Income_INR"].mean())

# %%
df["Credit_Score"] = df["Credit_Score"].fillna(df["Credit_Score"].mean())

# %%
df["Loan_Amount_INR"] = df["Loan_Amount_INR"].fillna(df["Loan_Amount_INR"].mean())

# %%
df["Interest_Rate_Pct"] = df["Interest_Rate_Pct"].fillna(df["Interest_Rate_Pct"].mean())

# %%
df["Loan_Term_Months"] = df["Loan_Term_Months"].fillna(df["Loan_Term_Months"].mean())

# %%
df["Monthly_EMI_INR"] = df["Monthly_EMI_INR"].fillna(df["Monthly_EMI_INR"].mean())

# %%
df["Outstanding_Balance_INR"] = df["Outstanding_Balance_INR"].fillna(df["Outstanding_Balance_INR"].mean())

# %%
df["Days_Past_Due"] = df["Days_Past_Due"].fillna(df["Days_Past_Due"].mean())

# %%
df["Late_Payment_Count"] = df["Late_Payment_Count"].fillna(df["Late_Payment_Count"].mean())

# %%
df["Debt_to_Income_Ratio"] = df["Debt_to_Income_Ratio"].fillna(df["Debt_to_Income_Ratio"].mean())

# %%
df["Debt_to_Income_Ratio"] = df["Debt_to_Income_Ratio"].fillna(df["Debt_to_Income_Ratio"].mean())

# %%
df["Investment_Value_INR"] = df["Investment_Value_INR"].fillna(df["Investment_Value_INR"].mean())

# %%
#for text/object column
df["Gender"] = df["Gender"].fillna("Unknown Gender")

# %%
df["City"] = df["City"].fillna("Unknown City")

# %%
df["Employment_Type"] = df["Employment_Type"].fillna("Unknown Employment_Type")

# %%
df.duplicated().sum()
# Out:
# np.int64(30)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1200, 28)

# %%
#unique values in each object column
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Non-Binary'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 3

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male          606
# Female        565
# Non-Binary     29
# Name: count, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Jaipur', 'Mumbai', 'Lucknow', 'Nashik', 'Chennai', 'Delhi',
#        'Indore', 'Ahmedabad', 'Bengaluru', 'Hyderabad', 'Pune', 'Thane',
#        'Surat', 'Kolkata', 'Nagpur'], dtype=object)

# %%
df['City'].nunique()
# Out:
# 15

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai       248
# Pune         166
# Bengaluru     85
# Delhi         81
# Thane         74
# Hyderabad     69
# Nashik        62
# Nagpur        62
# Chennai       59
# Surat         53
# Jaipur        50
# Lucknow       49
# Kolkata       49
# Indore        47
# Ahmedabad     46
# Name: count, dtype: int64

# %%
df['Employment_Type'].unique()
# Out:
# array(['Self-Employed', 'Salaried', 'Government Employee',
#        'Business Owner', 'Freelancer'], dtype=object)

# %%
df['Employment_Type'].nunique()
# Out:
# 5

# %%
df['Employment_Type'].value_counts()
# Out:
# Employment_Type
# Salaried               563
# Self-Employed          208
# Business Owner         168
# Freelancer             145
# Government Employee    116
# Name: count, dtype: int64

# %%
df.value_counts(["Gender","City"])
# Out:
# Gender      City
# Male        Mumbai       141
# Female      Mumbai        99
# Male        Pune          85
# Female      Pune          79
#             Bengaluru     47
#             Delhi         43
# Male        Delhi         38
#             Bengaluru     36
# Female      Thane         36
# Male        Thane         35
#             Hyderabad     35
#             Surat         32
# Female      Nagpur        32
#             Hyderabad     32
#             Nashik        31
# Male        Nashik        30
# Female      Chennai       29
# Male        Nagpur        29
#             Chennai       28
#             Ahmedabad     27
# Female      Lucknow       26
#             Jaipur        26
#             Indore        24
# Male        Jaipur        24
# Female      Kolkata       23
# Male        Lucknow       22
#             Kolkata       22
#             Indore        22
# Female      Ahmedabad     19
#             Surat         19
# Non-Binary  Mumbai         8
#             Kolkata        4
#             Thane          3
#             Bengaluru      2
#             Chennai        2
#             Hyderabad      2
#             Pune           2
#             Surat          2
#             Indore         1
#             Lucknow        1
#             Nagpur         1
#             Nashik         1
# Name: count, dtype: int64

# %%
df.value_counts(["Gender","Employment_Type"])
# Out:
# Gender      Employment_Type
# Male        Salaried               281
# Female      Salaried               274
# Male        Self-Employed          111
# Female      Self-Employed           90
# Male        Business Owner          82
# Female      Business Owner          79
#             Freelancer              70
# Male        Freelancer              70
#             Government Employee     62
# Female      Government Employee     52
# Non-Binary  Salaried                 8
#             Business Owner           7
#             Self-Employed            7
#             Freelancer               5
#             Government Employee      2
# Name: count, dtype: int64

# %%
df.value_counts(["City","Employment_Type"])
# Out:
# City       Employment_Type
# Mumbai     Salaried               110
# Pune       Salaried                76
# Mumbai     Self-Employed           52
# Bengaluru  Salaried                42
# Delhi      Salaried                38
#                                  ...
# Chennai    Business Owner           3
# Kolkata    Freelancer               3
# Lucknow    Government Employee      3
# Jaipur     Freelancer               2
# Indore     Government Employee      2
# Name: count, Length: 75, dtype: int64

# %%
#groupby()

# %%
df.columns
# Out:
# Index(['Record_ID', 'Customer_ID', 'Customer_Name', 'Age', 'Gender', 'City',
#        'Employment_Type', 'Annual_Income_INR', 'Credit_Score', 'Loan_Type',
#        'Loan_Amount_INR', 'Interest_Rate_Pct', 'Loan_Term_Months',
#        'Monthly_EMI_INR', 'Disbursement_Date', 'Outstanding_Balance_INR',
#        'Payment_Status', 'Days_Past_Due', 'Late_Payment_Count', 'Default_Flag',
#        'Debt_to_Income_Ratio', 'Savings_Balance_INR', 'Investment_Value_INR',
#        'Risk_Category', 'Last_Payment_Date', 'Payment_Mode',
#        'Acquisition_Channel', 'Branch_Name'],
#       dtype='object')

# %%
df.groupby("Gender")["Annual_Income_INR"].mean()
# Out:
# Gender
# Female        1.368431e+06
# Male          1.405117e+06
# Non-Binary    1.570141e+06
# Name: Annual_Income_INR, dtype: float64

# %%
df.groupby("Gender")["Annual_Income_INR"].max()
# Out:
# Gender
# Female        7218000.0
# Male          7292000.0
# Non-Binary    4404000.0
# Name: Annual_Income_INR, dtype: float64

# %%
df.groupby("Gender")["Annual_Income_INR"].min()
# Out:
# Gender
# Female        306000.0
# Male          294000.0
# Non-Binary    494000.0
# Name: Annual_Income_INR, dtype: float64

# %%
df.groupby("Loan_Type")["Loan_Amount_INR"].sum()
# Out:
# Loan_Type
# Business Loan     338690000
# Education Loan    169825000
# Gold Loan          53425000
# Home Loan         937635000
# Personal Loan     187300000
# Vehicle Loan      323160000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby(["Loan_Type","Risk_Category"])["Loan_Amount_INR"].sum()
# Out:
# Loan_Type       Risk_Category
# Business Loan   High              87005000
#                 Low               48055000
#                 Medium           203630000
# Education Loan  High              58830000
#                 Low               57480000
#                 Medium            53515000
# Gold Loan       High               1240000
#                 Low               18480000
#                 Medium            33705000
# Home Loan       High             383155000
#                 Low              144405000
#                 Medium           410075000
# Personal Loan   High              26700000
#                 Low               82290000
#                 Medium            78310000
# Vehicle Loan    High              71910000
#                 Low              106720000
#                 Medium           144530000
# Name: Loan_Amount_INR, dtype: int64

# %%
df.groupby(["Loan_Type","Risk_Category"])["Loan_Amount_INR"].sum().sort_values(ascending=False)
# Out:
# Loan_Type       Risk_Category
# Home Loan       Medium           410075000
#                 High             383155000
# Business Loan   Medium           203630000
# Vehicle Loan    Medium           144530000
# Home Loan       Low              144405000
# Vehicle Loan    Low              106720000
# Business Loan   High              87005000
# Personal Loan   Low               82290000
#                 Medium            78310000
# Vehicle Loan    High              71910000
# Education Loan  High              58830000
#                 Low               57480000
#                 Medium            53515000
# Business Loan   Low               48055000
# Gold Loan       Medium            33705000
# Personal Loan   High              26700000
# Gold Loan       Low               18480000
#                 High               1240000
# Name: Loan_Amount_INR, dtype: int64

# %%
#ASSIGNMENTS QUESTIONS & ANSWERS

# %%
#1.How many total loan records are present in the cleaned dataset?
df.shape
# Out:
# (1200, 28)

# %%
#2. How many unique customers are present in the dataset?
df['Customer_ID'].nunique()
# Out:
# 653

# %%
#        'CUST-00077', 'CUST-00458', 'CUST-00855', 'CUST-00662',
#        'CUST-00765', 'CUST-00860', 'CUST-00883', 'CUST-00718',
#        'CUST-00271', 'CUST-00367', 'CUST-00391', 'CUST-00766',
#        'CUST-00235', 'CUST-00452', 'CUST-00283', 'CUST-00031',
#        'CUST-00170', 'CUST-00155', 'CUST-00496', 'CUST-00745',
#        'CUST-00030'], dtype=object)

# %%
#5. How many unique cities, branches and employment categories are represented?
df["City"].nunique()
df["Branch_Name"].nunique()
df["Employment_Type"].nunique()
# Out:
# 5

# %%
#6. How many loan records belong to each loan type?
df["Loan_Type"].value_counts()
# Out:
# Loan_Type
# Personal Loan     356
# Vehicle Loan      242
# Home Loan         204
# Business Loan     167
# Education Loan    120
# Gold Loan         111
# Name: count, dtype: int64

# %%
#7. What percentage of the total loan records belongs to each loan type?

# %%
#8. Which loan type has the highest and lowest number of loan records?
df["Loan_Type"].value_counts().idxmax()
df["Loan_Type"].value_counts().idxmin()
# Out:
# 'Gold Loan'

# %%
#9. How many loan accounts fall under each payment-status category?
df["Payment_Status"].value_counts()
# Out:
# Payment_Status
# On Time    389
# Closed     385
# Late       229
# Missed     197
# Name: count, dtype: int64

# %%
#10. What percentage of accounts are on time, late, missed or closed?

# %%
#11. How many accounts fall under each risk category?
df["Risk_Category"].value_counts()
# Out:
# Risk_Category
# Medium    504
# Low       494
# High      202
# Name: count, dtype: int64

# %%
#12. What percentage of loan accounts are marked as defaulted?
df["Default_Flag"].value_counts(normalize=True) * 100
# Out:
# Default_Flag
# No     82.25
# Yes    17.75
# Name: proportion, dtype: float64

# %%
#13. Which five cities have the highest number of loan accounts?
df["City"].value_counts().head(5)
# Out:
# City
# Mumbai       248
# Pune         166
# Bengaluru     85
# Delhi         81
# Thane         74
# Name: count, dtype: int64

# %%
#14. How many unique customers are present in each city?
df.groupby("City")["Customer_ID"].nunique()
# Out:
# City
# Ahmedabad     46
# Bengaluru     81
# Chennai       57
# Delhi         78
# Hyderabad     69
# Indore        45
# Jaipur        48
# Kolkata       47
# Lucknow       47
# Mumbai       212
# Nagpur        60
# Nashik        57
# Pune         152
# Surat         51
# Thane         71
# Name: Customer_ID, dtype: int64

# %%
#15. Which employment type has the highest number of borrowers?
df["Employment_Type"].value_counts()
# Out:
# Employment_Type
# Salaried               563
# Self-Employed          208
# Business Owner         168
# Freelancer             145
# Government Employee    116
# Name: count, dtype: int64

# %%
#16. Which payment mode is used most frequently?
df["Payment_Mode"].value_counts().idxmax()
# Out:
# 'Auto-Debit'

# %%
#17. Which acquisition channel generates the highest number of loan records?
df["Acquisition_Channel"].value_counts().idxmax()
# Out:
# 'Mobile App'

# %%
#18. Which five branches handle the highest number of loan accounts?
df["Branch_Name"].value_counts().head(5)
# Out:
# Branch_Name
# Nagpur Civil Lines       134
# Nashik Road              130
# Pune Central             129
# Bengaluru MG Road        122
# Ahmedabad Navrangpura    120
# Name: count, dtype: int64

# %%
#19. What is the total sanctioned loan amount for each loan type?
df.groupby("Loan_Type")["Loan_Amount_INR"].sum()
# Out:
# Loan_Type
# Business Loan     338690000
# Education Loan    169825000
# Gold Loan          53425000
# Home Loan         937635000
# Personal Loan     187300000
# Vehicle Loan      323160000
# Name: Loan_Amount_INR, dtype: int64

# %%
#20. Which loan type has the highest total sanctioned loan amount?
df.groupby("Loan_Type")["Loan_Amount_INR"].sum().idxmax()
# Out:
# 'Home Loan'

# %%
#21. What are the average and median loan amounts for each loan type?
df.groupby("Loan_Type")["Loan_Amount_INR"].agg(["mean", "median"])
# Out:
#                         mean     median
# Loan_Type
# Business Loan   2.028084e+06  1830000.0
# Education Loan  1.415208e+06  1332500.0
# Gold Loan       4.813063e+05   385000.0
# Home Loan       4.596250e+06  4235000.0
# Personal Loan   5.261236e+05   460000.0
# Vehicle Loan    1.335372e+06  1210000.0

# %%
#22. What are the minimum and maximum loan amounts for each loan type?
df.groupby("Loan_Type")["Loan_Amount_INR"].agg(["min", "max"])
# Out:
#                    min       max
# Loan_Type
# Business Loan   250000   5400000
# Education Loan  140000   3735000
# Gold Loan        45000   1420000
# Home Loan       920000  11270000
# Personal Loan    65000   1430000
# Vehicle Loan    185000   3120000

# %%
#23. What is the average interest rate for each loan type?
df.groupby("Loan_Type")["Interest_Rate_Pct"].mean()
# Out:
# Loan_Type
# Business Loan     16.910487
# Education Loan    11.779373
# Gold Loan         13.607700
# Home Loan          9.546699
# Personal Loan     16.656390
# Vehicle Loan      11.806721
# Name: Interest_Rate_Pct, dtype: float64

# %%
#24. Which loan type has the highest average monthly EMI?
df.groupby("Loan_Type")["Monthly_EMI_INR"].mean()
# Out:
# Loan_Type
# Business Loan     84940.635509
# Education Loan    26300.832083
# Gold Loan         36128.699459
# Home Loan         58016.474657
# Personal Loan     23593.630899
# Vehicle Loan      34687.824545
# Name: Monthly_EMI_INR, dtype: float64

# %%
#25. What is the total outstanding balance for each loan type?
df.groupby("Loan_Type")["Outstanding_Balance_INR"].sum()
# Out:
# Loan_Type
# Business Loan     1.273775e+08
# Education Loan    1.101274e+08
# Gold Loan         1.101567e+07
# Home Loan         7.706345e+08
# Personal Loan     7.278132e+07
# Vehicle Loan      1.500851e+08
# Name: Outstanding_Balance_INR, dtype: float64

# %%
#26. Which payment-status category has the highest total outstanding balance?
df.groupby("Payment_Status")["Outstanding_Balance_INR"].sum()
# Out:
# Payment_Status
# Closed     5.172970e+06
# Late       4.060937e+08
# Missed     4.395105e+08
# On Time    3.912443e+08
# Name: Outstanding_Balance_INR, dtype: float64

# %%
#27. What is the average outstanding balance for on-time, late, missed and closed accounts?
df.groupby("Payment_Status")["Outstanding_Balance_INR"].mean()
# Out:
# Payment_Status
# Closed     1.343629e+04
# Late       1.773335e+06
# Missed     2.231018e+06
# On Time    1.005769e+06
# Name: Outstanding_Balance_INR, dtype: float64

# %%
#28. What is the average credit score for each loan type?
df.groupby("Loan_Type")["Credit_Score"].mean()
# Out:
# Loan_Type
# Business Loan     681.172806
# Education Loan    680.746212
# Gold Loan         674.426517
# Home Loan         682.446227
# Personal Loan     684.050732
# Vehicle Loan      692.338968
# Name: Credit_Score, dtype: float64

# %%
#29. What is the average credit score for each employment category?
df.groupby("Employment_Type")["Credit_Score"].mean()
# Out:
# Employment_Type
# Business Owner         691.160895
# Freelancer             662.269175
# Government Employee    700.791884
# Salaried               687.968190
# Self-Employed          672.268551
# Name: Credit_Score, dtype: float64

# %%
#30. What are the average and median annual incomes for each employment category?
df.groupby("Employment_Type")["Annual_Income_INR"].agg(["mean", "median"])
# Out:
#                              mean        median
# Employment_Type
# Business Owner       2.984251e+06  2.640500e+06
# Freelancer           9.110445e+05  8.820000e+05
# Government Employee  1.039967e+06  1.000000e+06
# Salaried             1.093905e+06  1.020000e+06
# Self-Employed        1.443450e+06  1.386089e+06

# %%
#31. What is the average debt-to-income ratio for each risk category?
df.groupby("Risk_Category")["Debt_to_Income_Ratio"].mean()
# Out:
# Risk_Category
# High      0.762786
# Low       0.331235
# Medium    0.627882
# Name: Debt_to_Income_Ratio, dtype: float64

# %%
#32. How do average credit score, annual income and loan amount vary across risk categories?
df.groupby("Risk_Category")[["Credit_Score",
                                   "Annual_Income_INR",
                                   "Loan_Amount_INR"]].mean()
# Out:
#                Credit_Score  Annual_Income_INR  Loan_Amount_INR
# Risk_Category
# High             637.274127       9.624176e+05     3.113069e+06
# Low              718.371958       1.698481e+06     9.259717e+05
# Medium           668.628467       1.263373e+06     1.832867e+06

# %%
#33. How many high-risk loan accounts are present in each city?
df[df["Risk_Category"]=="High"].groupby("City").size()
# Out:
# City
# Ahmedabad     7
# Bengaluru    15
# Chennai      12
# Delhi        14
# Hyderabad     4
# Indore        9
# Jaipur        6
# Kolkata       7
# Lucknow      11
# Mumbai       35
# Nagpur       13
# Nashik       14
# Pune         38
# Surat         7
# Thane        10
# dtype: int64

# %%
#34. Which loan type has the highest number of defaulted accounts?
df.groupby("Loan_Type")["Default_Flag"].sum()
# Out:
# Loan_Type
# Business Loan     NoNoNoNoNoYesNoNoNoNoYesNoNoYesNoNoNoYesNoNoNo...
# Education Loan    YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoYesNo...
# Gold Loan         NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# Home Loan         YesNoNoNoNoNoYesNoNoYesYesYesNoNoNoNoNoNoYesYe...
# Personal Loan     NoNoNoNoNoNoNoNoNoNoNoYesNoNoNoNoNoYesYesNoYes...
# Vehicle Loan      NoNoYesNoNoNoYesNoNoYesNoYesNoNoNoNoNoYesNoYes...
# Name: Default_Flag, dtype: object

# %%
#35. What is the default percentage for each loan type?

# %%
#36. Which employment category has the highest default percentage?

# %%
#37. Which loan type has the highest number of late or missed-payment accounts?

# %%
#38. What are the top ten customers by total sanctioned loan amount?
df.groupby("Customer_ID")["Loan_Amount_INR"].sum().nlargest(10)
# Out:
# Customer_ID
# CUST-00049    16020000
# CUST-00539    14405000
# CUST-00873    13645000
# CUST-00174    13095000
# CUST-00223    12930000
# CUST-00318    12785000
# CUST-00528    12565000
# CUST-00217    12445000
# CUST-00267    12155000
# CUST-00867    12080000
# Name: Loan_Amount_INR, dtype: int64

# %%
#39. What are the top ten loan accounts by outstanding balance?

# %%
#40. How do the number and total value of loan disbursements vary by year and loan type?
